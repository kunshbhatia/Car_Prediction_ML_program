# %%
import pandas as pd

# %%
df = pd.read_csv("Vehicle Price.csv")
df
# Out:
#                                                 name  \
# 0                       2024 Jeep Wagoneer Series II
# 1                    2024 Jeep Grand Cherokee Laredo
# 2                           2024 GMC Yukon XL Denali
# 3                         2023 Dodge Durango Pursuit
# 4                              2024 RAM 3500 Laramie
# ...                                              ...
# 997   2024 Mercedes-Benz Sprinter 2500 Standard Roof
# 998           2024 Dodge Hornet Hornet R/T Plus Eawd
# 999                          2024 Jeep Wagoneer Base
# 1000           2024 Nissan Murano SV Intelligent AWD
# 1001                2024 Chevrolet Silverado 2500 WT
#
#                                             description           make  \
# 0     \n      \n        Heated Leather Seats, Nav Sy...           Jeep
# 1     Al West is committed to offering every custome...           Jeep
# 2                                                   NaN            GMC
# ...

# %%
df.columns
# Out:
# Index(['name', 'description', 'make', 'model', 'year', 'price', 'fuel',
#        'mileage', 'transmission', 'body', 'doors', 'exterior_color',
#        'interior_color', 'drivetrain'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# name               0
# description       56
# make               0
# model              0
# year               0
# price             23
# fuel               7
# mileage           34
# transmission       2
# body               3
# doors              7
# exterior_color     5
# interior_color    38
# drivetrain         0
# dtype: int64

# %%
df.drop(["name","description",'exterior_color',"interior_color"],axis=1,inplace=True)

# %%
df.drop_duplicates(inplace=True)

# %%
df['price'] = df['price'].fillna(df['price'].mode()[0])

# %%
df['fuel'] = df['fuel'].fillna('Electric') # As all cars having nan are electric , you can check also

# %%
df['mileage'] = df['mileage'].fillna(df['mileage'].median())

# %%
# Checked the correct data from internet
df.loc[725,"transmission"] = "1-Speed Automatic"
df.loc[940,"transmission"] = '10-Speed Automatic with Overdrive'
df['doors'] = df['doors'].fillna(4)

# %%
df['body'] = df['body'].fillna(df['body'].mode()[0])

# %%
df.isnull().sum() # All Set
# Out:
# make            0
# model           0
# year            0
# price           0
# fuel            0
# mileage         0
# transmission    0
# body            0
# doors           0
# drivetrain      0
# dtype: int64

# %%
df.reset_index(drop=True,inplace=True)
df
# Out:
#               make           model  year    price      fuel  mileage  \
# 0             Jeep        Wagoneer  2024  74600.0  Gasoline     10.0
# 1             Jeep  Grand Cherokee  2024  50170.0  Gasoline      1.0
# 2              GMC        Yukon XL  2024  96410.0  Gasoline      0.0
# 3            Dodge         Durango  2023  46835.0  Gasoline     32.0
# 4              RAM            3500  2024  81663.0    Diesel     10.0
# ..             ...             ...   ...      ...       ...      ...
# 938            RAM            2500  2024  69315.0    Diesel      0.0
# 939  Mercedes-Benz   Sprinter 2500  2024  59037.0    Diesel     10.0
# 940           Jeep        Wagoneer  2024  69085.0  Gasoline     20.0
# 941         Nissan          Murano  2024  43495.0  Gasoline      6.0
# 942      Chevrolet  Silverado 2500  2024  48995.0  Gasoline     31.0
#
#           transmission          body  doors        drivetrain
# 0    8-Speed Automatic           SUV    4.0  Four-wheel Drive
# ...

# %%
df.to_csv("Vehicle_final.csv") # Saving The Fresh Data
